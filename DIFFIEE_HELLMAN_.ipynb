# %% [markdown]
# <a href="https://colab.research.google.com/github/Annapurna0220/11239A066_DBS_RECORD/blob/main/DIFFIEE_HELLMAN_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def power(a,b,m): return pow(a,b,m)

n=int(input("Enter n (prime): "))
g=int(input("Enter g (generator): "))
x=int(input("Enter x (person 1): "))
y=int(input("Enter y (person 2): "))

a,b=power(g,x,n),power(g,y,n)
k1,k2=power(b,x,n),power(a,y,n)

print("Key for the first person:",k1)
print("Key for the second person:",k2)
7
# Out:
# Enter n (prime): 7
# Enter g (generator): 7
# Enter x (person 1): 6
# Enter y (person 2): 9
# Key for the first person: 0
# Key for the second person: 0

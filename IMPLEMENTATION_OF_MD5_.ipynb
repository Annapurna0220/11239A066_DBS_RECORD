# %% [markdown]
# <a href="https://colab.research.google.com/github/Annapurna0220/11239A066_DBS_RECORD/blob/main/IMPLEMENTATION_OF_MD5_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import hashlib

msg = input("Enter message: ")
res = hashlib.md5(msg.encode()).hexdigest()

print("\n\tMD5 ENCRYPTION ALGORITHM IN PYTHON\n")
print(f"Input String to be Encrypted using MD5 :\n\t{msg}")
print("\nThe MD5 code for input string is:")
print(f"\t= 0x{res}")
print("\n\tMD5 Encryption Successfully Completed!!!\n")
# Out:
# Enter message: the quick dog cameand ate the rate
#
# 	MD5 ENCRYPTION ALGORITHM IN PYTHON
#
# Input String to be Encrypted using MD5 :
# 	the quick dog cameand ate the rate
#
# The MD5 code for input string is:
# 	= 0xd65772f44488ec7c228895c262d8e346
#
# 	MD5 Encryption Successfully Completed!!!
